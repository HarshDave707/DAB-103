# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshDave707/DAB-103/blob/load-dataset/dab_103.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

vehicle_dataset_url = 'https://data.wa.gov/api/views/f6w7-q2d2/rows.csv'

vehicle_df = pd.read_csv(vehicle_dataset_url)

vehicle_df
# Out:
#         VIN (1-10)     County               City State  Postal Code  \
# 0       5YJ3E1EB2J    Suffolk            Suffolk    VA      23435.0
# 1       5YJ3E1ECXL     Yakima             Yakima    WA      98908.0
# 2       WA1LAAGE7M     Yakima             Yakima    WA      98908.0
# 3       5YJ3E1EA1K   Danville           Danville    VA      24541.0
# 4       1FADP5CU9E    Norfolk            Norfolk    VA      23518.0
# ...            ...        ...                ...   ...          ...
# 121973  5YJYGDEE2M       King           Issaquah    WA      98027.0
# 121974  1N4BZ0CP1H  Snohomish           Lynnwood    WA      98037.0
# 121975  5YJYGDEFXL  Snohomish  Mountlake Terrace    WA      98043.0
# 121976  1N4BZ1CPXK       King            Seattle    WA      98118.0
# 121977  1FTVW1ELXN       King           Kirkland    WA      98034.0
#
#         Model Year    Make    Model                   Electric Vehicle Type  \
# 0             2018   TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 1             2020   TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 2             2021    AUDI   E-TRON          Battery Electric Vehicle (BEV)
# 3             2019   TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 4             2014    FORD    C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
# ...            ...     ...      ...                                     ...
# 121973        2021   TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 121974        2017  NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 121975        2020   TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 121976        2019  NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 121977        2022    FORD    F-150          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                 Clean Alternative Fuel Vehicle Eligible             215
# 1                 Clean Alternative Fuel Vehicle Eligible             308
# 2                 Clean Alternative Fuel Vehicle Eligible             222
# 3                 Clean Alternative Fuel Vehicle Eligible             220
# 4                   Not eligible due to low battery range              19
# ...                                                   ...             ...
# 121973  Eligibility unknown as battery range has not b...               0
# 121974            Clean Alternative Fuel Vehicle Eligible             107
# 121975            Clean Alternative Fuel Vehicle Eligible             291
# 121976            Clean Alternative Fuel Vehicle Eligible             150
# 121977  Eligibility unknown as battery range has not b...               0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 0               0                   NaN       476647986
# 1               0                  14.0       103490145
# 2               0                  14.0       144941534
# 3               0                   NaN       168513922
# 4               0                   NaN       150749378
# ...           ...                   ...             ...
# 121973          0                  41.0       179180543
# 121974          0                  32.0       177995058
# 121975          0                  32.0       106429655
# 121976          0                  37.0       100595218
# 121977          0                   1.0       223872554
#
#                    Vehicle Location  \
# 0         POINT (-76.42443 36.8752)
# 1       POINT (-120.56916 46.58514)
# 2       POINT (-120.56916 46.58514)
# 3         POINT (-79.4172 36.58598)
# 4        POINT (-76.21549 36.92478)
# ...                             ...
# 121973   POINT (-122.03439 47.5301)
# 121974  POINT (-122.27734 47.83785)
# 121975  POINT (-122.31111 47.78803)
# 121976   POINT (-122.2668 47.55115)
# 121977  POINT (-122.22901 47.72201)
#
#                                      Electric Utility  2020 Census Tract
# 0                                                 NaN       5.180008e+10
# 1                                          PACIFICORP       5.307700e+10
# 2                                          PACIFICORP       5.307700e+10
# 3                                                 NaN       5.159000e+10
# 4                                                 NaN       5.171001e+10
# ...                                               ...                ...
# 121973  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 121974                         PUGET SOUND ENERGY INC       5.306105e+10
# 121975                         PUGET SOUND ENERGY INC       5.306105e+10
# 121976   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 121977  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
#
# [121978 rows x 17 columns]

# %%
vehicle_df.drop ( columns= ['VIN (1-10)',
                            'Base MSRP',
                            'Legislative District',
                            'Vehicle Location',
                            'Vehicle Location',
                            'Electric Utility',
                            '2020 Census Tract'],inplace=True)

# %%
vehicle_df
# Out:
#            County               City State  Postal Code  Model Year    Make  \
# 0         Suffolk            Suffolk    VA      23435.0        2018   TESLA
# 1          Yakima             Yakima    WA      98908.0        2020   TESLA
# 2          Yakima             Yakima    WA      98908.0        2021    AUDI
# 3        Danville           Danville    VA      24541.0        2019   TESLA
# 4         Norfolk            Norfolk    VA      23518.0        2014    FORD
# ...           ...                ...   ...          ...         ...     ...
# 121973       King           Issaquah    WA      98027.0        2021   TESLA
# 121974  Snohomish           Lynnwood    WA      98037.0        2017  NISSAN
# 121975  Snohomish  Mountlake Terrace    WA      98043.0        2020   TESLA
# 121976       King            Seattle    WA      98118.0        2019  NISSAN
# 121977       King           Kirkland    WA      98034.0        2022    FORD
#
#           Model                   Electric Vehicle Type  \
# 0       MODEL 3          Battery Electric Vehicle (BEV)
# 1       MODEL 3          Battery Electric Vehicle (BEV)
# 2        E-TRON          Battery Electric Vehicle (BEV)
# 3       MODEL 3          Battery Electric Vehicle (BEV)
# 4         C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
# ...         ...                                     ...
# 121973  MODEL Y          Battery Electric Vehicle (BEV)
# 121974     LEAF          Battery Electric Vehicle (BEV)
# 121975  MODEL Y          Battery Electric Vehicle (BEV)
# 121976     LEAF          Battery Electric Vehicle (BEV)
# 121977    F-150          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                 Clean Alternative Fuel Vehicle Eligible             215
# 1                 Clean Alternative Fuel Vehicle Eligible             308
# 2                 Clean Alternative Fuel Vehicle Eligible             222
# 3                 Clean Alternative Fuel Vehicle Eligible             220
# 4                   Not eligible due to low battery range              19
# ...                                                   ...             ...
# 121973  Eligibility unknown as battery range has not b...               0
# 121974            Clean Alternative Fuel Vehicle Eligible             107
# 121975            Clean Alternative Fuel Vehicle Eligible             291
# 121976            Clean Alternative Fuel Vehicle Eligible             150
# 121977  Eligibility unknown as battery range has not b...               0
#
#         DOL Vehicle ID
# 0            476647986
# 1            103490145
# 2            144941534
# 3            168513922
# 4            150749378
# ...                ...
# 121973       179180543
# 121974       177995058
# 121975       106429655
# 121976       100595218
# 121977       223872554
#
# [121978 rows x 11 columns]

# %%
null_counts = vehicle_df.isnull().sum()
print(null_counts)
# Out:
# County                                                 2
# City                                                   2
# State                                                  0
# Postal Code                                            2
# Model Year                                             0
# Make                                                   0
# Model                                                104
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# DOL Vehicle ID                                         0
# dtype: int64

# %%
null_County_row = vehicle_df[vehicle_df['County'].isnull()]
vehicle_df = vehicle_df.dropna(subset=['County'])

# %%
vehicle_df['Model'].fillna(value="not defined", inplace=True)

# %%
null_counts = vehicle_df.isnull().sum()
print(null_counts)
# Out:
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# DOL Vehicle ID                                       0
# dtype: int64

# %%
vehicle_df
# Out:
#            County               City State Postal Code  Model Year    Make  \
# 0         Suffolk            Suffolk    VA     23435.0        2018   TESLA
# 1          Yakima             Yakima    WA     98908.0        2020   TESLA
# 2          Yakima             Yakima    WA     98908.0        2021    AUDI
# 3        Danville           Danville    VA     24541.0        2019   TESLA
# 4         Norfolk            Norfolk    VA     23518.0        2014    FORD
# ...           ...                ...   ...         ...         ...     ...
# 121973       King           Issaquah    WA     98027.0        2021   TESLA
# 121974  Snohomish           Lynnwood    WA     98037.0        2017  NISSAN
# 121975  Snohomish  Mountlake Terrace    WA     98043.0        2020   TESLA
# 121976       King            Seattle    WA     98118.0        2019  NISSAN
# 121977       King           Kirkland    WA     98034.0        2022    FORD
#
#           Model                   Electric Vehicle Type  \
# 0       MODEL 3          Battery Electric Vehicle (BEV)
# 1       MODEL 3          Battery Electric Vehicle (BEV)
# 2        E-TRON          Battery Electric Vehicle (BEV)
# 3       MODEL 3          Battery Electric Vehicle (BEV)
# 4         C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
# ...         ...                                     ...
# 121973  MODEL Y          Battery Electric Vehicle (BEV)
# 121974     LEAF          Battery Electric Vehicle (BEV)
# 121975  MODEL Y          Battery Electric Vehicle (BEV)
# 121976     LEAF          Battery Electric Vehicle (BEV)
# 121977    F-150          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                 Clean Alternative Fuel Vehicle Eligible             215
# 1                 Clean Alternative Fuel Vehicle Eligible             308
# 2                 Clean Alternative Fuel Vehicle Eligible             222
# 3                 Clean Alternative Fuel Vehicle Eligible             220
# 4                   Not eligible due to low battery range              19
# ...                                                   ...             ...
# 121973  Eligibility unknown as battery range has not b...               0
# 121974            Clean Alternative Fuel Vehicle Eligible             107
# 121975            Clean Alternative Fuel Vehicle Eligible             291
# 121976            Clean Alternative Fuel Vehicle Eligible             150
# 121977  Eligibility unknown as battery range has not b...               0
#
#         DOL Vehicle ID
# 0            476647986
# 1            103490145
# 2            144941534
# 3            168513922
# 4            150749378
# ...                ...
# 121973       179180543
# 121974       177995058
# 121975       106429655
# 121976       100595218
# 121977       223872554
#
# [121978 rows x 11 columns]

# %%
charging_station_dataset_url = ('https://developer.nrel.gov/api/alt-fuel-stations/v1.csv?'
       'api_key=5gylZXuJK3qHQRwp8SyfTgtlomhXSCWSlfyA7y3P'
       '&status=E'
       '&access=public'
       '&fuel_type=ELEC'
       '&country=US'
       )

charging_station_vehicle_df = pd.read_csv(charging_station_dataset_url)

charging_station_vehicle_df
# Out:
# <ipython-input-3-34d15d0edbad>:9: DtypeWarning: Columns (6,20,31,46,69) have mixed types. Specify dtype option on import or set low_memory=False.
#   charging_station_vehicle_df = pd.read_csv(charging_station_dataset_url)
#       Fuel Type Code                                      Station Name  \
# 0               ELEC                     Los Angeles Convention Center
# 1               ELEC                    California Air Resources Board
# 2               ELEC                            Scripps Green Hospital
# 3               ELEC                                     Galpin Motors
# 4               ELEC                                 Galleria at Tyler
# ...              ...                                               ...
# 52131           ELEC  Center of Excellence (For Testing Purposes Only)
# 52132           ELEC                                  HG&E Main Office
# 52133           ELEC                        Hood River Fire Department
# 52134           ELEC                         Cummins- Briston PA Fleet
# 52135           ELEC                    Bayer Chevrolet Buick Cadillac
#
#                 Street Address             Intersection Directions  \
# 0           1201 S Figueroa St            West hall and South hall
# 1             9530 Telstar Ave                                 NaN
# 2      10666 N Torrey Pines Rd  Patient Parking Structure, level G
# 3            15421 Roscoe Blvd                                 NaN
# 4       1299 Galleria at Tyler                                 NaN
# ...                        ...                                 ...
# 52131        300 Victory Drive                                 NaN
# 52132        99 Suffolk Street                                 NaN
# 52133          1785 Meyer Pkwy                                 NaN
# 52134           2727 Ford Road                                 NaN
# 52135          601 W Walker St                                 NaN
#
#                City State    ZIP  Plus4 Station Phone Status Code  ...  \
# 0       Los Angeles    CA  90015    NaN  213-741-1151           E  ...
# 1          El Monte    CA  91731    NaN  626-575-6800           E  ...
# 2          La Jolla    CA  92037    NaN           NaN           E  ...
# 3         Sepulveda    CA  91343    NaN  800-256-6219           E  ...
# 4         Riverside    CA  92503    NaN  951-351-3110           E  ...
# ...             ...   ...    ...    ...           ...         ...  ...
# 52131       Herndon    VA  20170    NaN  833-632-2778           E  ...
# 52132       Holyoke    MA  01040    NaN  888-356-8911           E  ...
# 52133    Hood River    OR  97031    NaN  855-885-9571           E  ...
# 52134       Briston    PA  19007    NaN  855-885-9571           E  ...
# 52135  Breckenridge    TX  76424    NaN  866-816-7584           E  ...
#
#        CNG PSI CNG Vehicle Class LNG Vehicle Class  \
# 0          NaN               NaN               NaN
# 1          NaN               NaN               NaN
# 2          NaN               NaN               NaN
# 3          NaN               NaN               NaN
# 4          NaN               NaN               NaN
# ...        ...               ...               ...
# 52131      NaN               NaN               NaN
# 52132      NaN               NaN               NaN
# 52133      NaN               NaN               NaN
# 52134      NaN               NaN               NaN
# 52135      NaN               NaN               NaN
#
#       EV On-Site Renewable Source  Restricted Access  RD Blends  \
# 0                             NaN              False        NaN
# 1                             NaN              False        NaN
# 2                             NaN              False        NaN
# 3                             NaN              False        NaN
# 4                             NaN              False        NaN
# ...                           ...                ...        ...
# 52131                         NaN                NaN        NaN
# 52132                         NaN                NaN        NaN
# 52133                         NaN                NaN        NaN
# 52134                         NaN                NaN        NaN
# 52135                         NaN                NaN        NaN
#
#        RD Blends (French)  RD Blended with Biodiesel  \
# 0                     NaN                        NaN
# 1                     NaN                        NaN
# 2                     NaN                        NaN
# 3                     NaN                        NaN
# 4                     NaN                        NaN
# ...                   ...                        ...
# 52131                 NaN                        NaN
# 52132                 NaN                        NaN
# 52133                 NaN                        NaN
# 52134                 NaN                        NaN
# 52135                 NaN                        NaN
#
#        RD Maximum Biodiesel Level  NPS Unit Name
# 0                             NaN            NaN
# 1                             NaN            NaN
# 2                             NaN            NaN
# 3                             NaN            NaN
# 4                             NaN            NaN
# ...                           ...            ...
# 52131                         NaN            NaN
# 52132                         NaN            NaN
# 52133                         NaN            NaN
# 52134                         NaN            NaN
# 52135                         NaN            NaN
#
# [52136 rows x 70 columns]

# %%
charging_station_vehicle_df.drop(columns=['Intersection Directions', 'Plus4', 'Expected Date', 
                                          'Groups With Access Code', 'Cards Accepted', 'BD Blends', 
                                          'NG Fill Type Code', 'NG PSI', 'EV Other Info', 
                                          'EV Network', 'EV Network Web', 'Date Last Confirmed', 
                                          'Updated At', 'Federal Agency ID', 'Federal Agency Name', 
                                          'Open Date', 'Hydrogen Status Link', 'NG Vehicle Class', 
                                          'LPG Primary', 'E85 Blender Pump', 'Intersection Directions (French)', 
                                          'Access Days Time (French)', 'BD Blends (French)', 'Groups With Access Code (French)', 
                                          'Hydrogen Is Retail', 'Access Code', 'Access Detail Code', 
                                          'Federal Agency Code', 'Facility Type', 'CNG Dispenser Num', 
                                          'CNG On-Site Renewable Source', 'CNG Total Compression Capacity', 
                                          'CNG Storage Capacity', 'LNG On-Site Renewable Source', 
                                          'E85 Other Ethanol Blends', 'EV Pricing', 'EV Pricing (French)', 
                                          'LPG Nozzle Types', 'Hydrogen Pressures', 'Hydrogen Standards', 
                                          'CNG Fill Type Code', 'CNG PSI', 'CNG Vehicle Class', 'LNG Vehicle Class', 
                                          'EV On-Site Renewable Source', 'Restricted Access', 'RD Blends', 
                                          'RD Blends (French)', 'RD Blended with Biodiesel', 'RD Maximum Biodiesel Level', 
                                          'NPS Unit Name'], inplace=True)

# %%
charging_station_vehicle_df
# Out:
#       Fuel Type Code                                      Station Name  \
# 0               ELEC                     Los Angeles Convention Center
# 1               ELEC                    California Air Resources Board
# 2               ELEC                            Scripps Green Hospital
# 3               ELEC                                     Galpin Motors
# 4               ELEC                                 Galleria at Tyler
# ...              ...                                               ...
# 52131           ELEC  Center of Excellence (For Testing Purposes Only)
# 52132           ELEC                                  HG&E Main Office
# 52133           ELEC                        Hood River Fire Department
# 52134           ELEC                         Cummins- Briston PA Fleet
# 52135           ELEC                    Bayer Chevrolet Buick Cadillac
#
#                 Street Address          City State    ZIP Station Phone  \
# 0           1201 S Figueroa St   Los Angeles    CA  90015  213-741-1151
# 1             9530 Telstar Ave      El Monte    CA  91731  626-575-6800
# 2      10666 N Torrey Pines Rd      La Jolla    CA  92037           NaN
# 3            15421 Roscoe Blvd     Sepulveda    CA  91343  800-256-6219
# 4       1299 Galleria at Tyler     Riverside    CA  92503  951-351-3110
# ...                        ...           ...   ...    ...           ...
# 52131        300 Victory Drive       Herndon    VA  20170  833-632-2778
# 52132        99 Suffolk Street       Holyoke    MA  01040  888-356-8911
# 52133          1785 Meyer Pkwy    Hood River    OR  97031  855-885-9571
# 52134           2727 Ford Road       Briston    PA  19007  855-885-9571
# 52135          601 W Walker St  Breckenridge    TX  76424  866-816-7584
#
#       Status Code           Access Days Time  EV Level1 EVSE Num  \
# 0               E        5:30am-9pm; pay lot                 NaN
# 1               E             24 hours daily                 NaN
# 2               E             24 hours daily                 NaN
# 3               E  Dealership business hours                 NaN
# 4               E             6am-12am daily                 NaN
# ...           ...                        ...                 ...
# 52131           E             24 hours daily                 NaN
# 52132           E             24 hours daily                 NaN
# 52133           E                        NaN                 NaN
# 52134           E                        NaN                 NaN
# 52135           E                        NaN                 NaN
#
#        EV Level2 EVSE Num  EV DC Fast Count Geocode Status   Latitude  \
# 0                     7.0               NaN            GPS  34.040539
# 1                     3.0               NaN            GPS  34.068720
# 2                     1.0               NaN            GPS  32.899470
# 3                     2.0               NaN          200-9  34.221665
# 4                     4.0               NaN            GPS  33.909914
# ...                   ...               ...            ...        ...
# 52131                 NaN               1.0            GPS  38.957440
# 52132                 2.0               NaN          200-8  42.207190
# 52133                 1.0               NaN            GPS  45.703330
# 52134                 2.0               NaN            GPS  40.119151
# 52135                 1.0               NaN            GPS  32.755116
#
#         Longitude      ID Owner Type Code EV Connector Types Country
# 0     -118.271387    1523               P              J1772      US
# 1     -118.064000    1583              SG              J1772      US
# 2     -117.243000    6355               P              J1772      US
# 3     -118.468371    6405               P              J1772      US
# 4     -117.459053    6425               P              J1772      US
# ...           ...     ...             ...                ...     ...
# 52131  -77.378810  258294             NaN         J1772COMBO      US
# 52132  -72.610530  258303             NaN              J1772      US
# 52133 -121.529720  258304             NaN              J1772      US
# 52134  -74.890009  258305             NaN              J1772      US
# 52135  -98.909056  258306             NaN              J1772      US
#
# [52136 rows x 19 columns]

# %%
null_counts = charging_station_vehicle_df.isnull().sum()
print(null_counts)
# Out:
# Fuel Type Code            0
# Station Name              1
# Street Address            0
# City                      0
# State                    23
# ZIP                       0
# Station Phone           596
# Status Code               0
# Access Days Time       8314
# EV Level1 EVSE Num    51939
# EV Level2 EVSE Num     6114
# EV DC Fast Count      44954
# Geocode Status            0
# Latitude                  0
# Longitude                 0
# ID                        0
# Owner Type Code       38713
# EV Connector Types       24
# Country                   0
# dtype: int64

# %%
null_state_row = charging_station_vehicle_df[charging_station_vehicle_df['State'].isnull()]
print(null_state_row)
# Out:
#       Fuel Type Code                                     Station Name  \
# 45702           ELEC                                     LA Test site
# 50552           ELEC                                    Yucca Library
# 50557           ELEC                      Cabana Encanto - Building A
# 50694           ELEC  ABM - Carl Black Chevrolet Buick GMC of Orlando
# 50744           ELEC                            DE PACIFIC 12100, LLC
# 50832           ELEC                       ABM - CADILLAC OF PORTLAND
# 51042           ELEC                    Marriott Courtyard Paramus NJ
# 51160           ELEC          University of California - Bellevue Lot
# 51307           ELEC                            Fields BMW Northfield
# 51666           ELEC                             Smart Charge America
# 51676           ELEC                           Cortland at Stonebriar
# 51677           ELEC               Florida Kennels Inc - Las Carreras
# 51685           ELEC             ABM - Coastal Chevrolet Cadillac Inc
# 51687           ELEC                           ABM - Ray Skillman GMC
# 51689           ELEC                          DAEYOUNG CHAEVI (Korea)
# 51747           ELEC                                      Page Street
# 51751           ELEC                                   Voya Financial
# 51781           ELEC    Firestone Complete Auto Care - Diagonal Plaza
# 51787           ELEC                         Satori Frisco Apartments
# 51795           ELEC                                    Bed Expansion
# 51797           ELEC           Phoenix Convention Center North Garage
# 51800           ELEC                       Leith Ford - Non-Networked
# 52076           ELEC                        EchoPark Sonic Automotive
#
#                               Street Address                 City State  \
# 45702                  3355 Las Vegas Blvd S           Long Beach   NaN
# 50552                        5648 N 15th Ave              Phoenix   NaN
# 50557                          2323 150th Dr             Goodyear   NaN
# 50694                11500 East Colonial Dr.              Orlando   NaN
# 50744               12100 Wilshire Boulevard         Santa Monica   NaN
# 50832                    9141 SW Canyon Road             Portland   NaN
# 51042                           320 Route 17              Paramus   NaN
# 51160                         5200 N Lake Rd               Merced   NaN
# 51307                    700 W Frontage Road           Northfield   NaN
# 51666                    2016 Centimeter Cir               Austin   NaN
# 51676                        3030 Ohio Drive               Frisco   NaN
# 51677                         7218 W 4th Ave              Hialeah   NaN
# 51685                         8559 Ocean Hwy       Pawleys Island   NaN
# 51687                           8424 US 31 S         Indianapolis   NaN
# 51689  25, Techno sunhwan-ro 7-gil, Yuga-eup  Dalseong-gun, Daegu   NaN
# 51747                        333 Page Street             San Jose   NaN
# 51751          7337 E. Doubletree Ranch Road           Scottsdale   NaN
# 51781                           3395 30th St              Boulder   NaN
# 51787                     11900 Research Rd.               Frisco   NaN
# 51795                    2400 Round Rock Ave           Round Rock   NaN
# 51797                   475 E. Monroe Street              Phoenix   NaN
# 51800                   5300 Rolesville Road              Wendell   NaN
# 52076                        4401 Colwick Rd            Charlotte   NaN
#
#          ZIP Station Phone Status Code Access Days Time  EV Level1 EVSE Num  \
# 45702  90808  877-455-3833           E   24 hours daily                 NaN
# 50552  85015  888-998-2546           E              NaN                 NaN
# 50557  85395  888-998-2546           E              NaN                 NaN
# 50694  32817  888-998-2546           E              NaN                 NaN
# 50744  90403  888-998-2546           E              NaN                 NaN
# 50832  97225  888-998-2546           E              NaN                 NaN
# 51042   7652  888-998-2546           E              NaN                 NaN
# 51160  95343  888-998-2546           E              NaN                 NaN
# 51307  60093  888-998-2546           E              NaN                 NaN
# 51666  78758  888-998-2546           E              NaN                 NaN
# 51676  75035  888-998-2546           E              NaN                 NaN
# 51677  33014  888-998-2546           E              NaN                 NaN
# 51685  29585  888-998-2546           E              NaN                 NaN
# 51687  46227  888-998-2546           E              NaN                 NaN
# 51689  43023  888-998-2546           E              NaN                 NaN
# 51747  95126  888-998-2546           E              NaN                 NaN
# 51751  85258  888-998-2546           E              NaN                 NaN
# 51781  80301  888-998-2546           E              NaN                 NaN
# 51787  75033  888-998-2546           E              NaN                 NaN
# 51795  78681  888-998-2546           E              NaN                 NaN
# 51797  85004  888-998-2546           E              NaN                 NaN
# 51800  27591  888-998-2546           E              NaN                 NaN
# 52076  28211  888-998-2546           E              NaN                 NaN
#
#        EV Level2 EVSE Num  EV DC Fast Count Geocode Status   Latitude  \
# 45702                 NaN               1.0            GPS  12.921876
# 50552                 2.0               NaN            GPS   1.000000
# 50557                 4.0               NaN            GPS   1.000000
# 50694                 1.0               NaN            GPS   1.000000
# 50744                 2.0               NaN            GPS   0.000000
# 50832                 1.0               NaN            GPS   1.000000
# 51042                 4.0               NaN            GPS   1.000000
# 51160                13.0               NaN            GPS   1.000000
# 51307                 NaN               1.0            GPS   1.000000
# 51666                 1.0               NaN            GPS   1.000000
# 51676                 2.0               NaN            GPS   0.000000
# 51677                 5.0               NaN            GPS   1.000000
# 51685                 2.0               NaN            GPS   1.000000
# 51687                 1.0               NaN            GPS   1.000000
# 51689                 1.0               NaN            GPS   1.000000
# 51747                 2.0               NaN            GPS   1.000000
# 51751                 2.0               NaN            GPS   1.000000
# 51781                 1.0               NaN            GPS   1.000000
# 51787                 3.0               NaN            GPS   1.000000
# 51795                 4.0               NaN            GPS   0.000000
# 51797                 4.0               NaN            GPS   1.000000
# 51800                 1.0               NaN            GPS   1.000000
# 52076                 NaN               1.0            GPS   0.000000
#
#         Longitude      ID Owner Type Code  EV Connector Types Country
# 45702 -164.848855  234510             NaN  CHADEMO J1772COMBO      US
# 50552    1.000000  255152             NaN               J1772      US
# 50557    1.000000  255165             NaN               J1772      US
# 50694   -1.000000  255355             NaN               J1772      US
# 50744    0.000000  255442             NaN               J1772      US
# 50832   -1.000000  255611             NaN               J1772      US
# 51042    1.000000  256204             NaN               J1772      US
# 51160    1.000000  256366             NaN               J1772      US
# 51307    1.000000  256680             NaN          J1772COMBO      US
# 51666   -1.000000  257393             NaN               J1772      US
# 51676    0.000000  257406             NaN               J1772      US
# 51677    1.000000  257407             NaN               J1772      US
# 51685   -1.000000  257415             NaN               J1772      US
# 51687   -1.000000  257417             NaN               J1772      US
# 51689   -1.000000  257419             NaN               J1772      US
# 51747   -1.000000  257480             NaN               J1772      US
# 51751   -1.000000  257484             NaN               J1772      US
# 51781   -1.000000  257514             NaN               J1772      US
# 51787    1.000000  257521             NaN               J1772      US
# 51795    0.000000  257529             NaN               J1772      US
# 51797   -1.000000  257531             NaN               J1772      US
# 51800   -1.000000  257534             NaN               J1772      US
# 52076    0.000000  258220             NaN          J1772COMBO      US

# %%
null_state_row = charging_station_vehicle_df[charging_station_vehicle_df['State'].isnull()]
city_value = null_state_row['City'].values[0:23]
print(city_value)
# Out:
# ['Long Beach' 'Phoenix' 'Goodyear' 'Orlando' 'Santa Monica' 'Portland'
#  'Paramus' 'Merced' 'Northfield' 'Austin' 'Frisco' 'Hialeah'
#  'Pawleys Island' 'Indianapolis' 'Dalseong-gun, Daegu' 'San Jose'
#  'Scottsdale' 'Boulder' 'Frisco' 'Round Rock' 'Phoenix' 'Wendell'
#  'Charlotte']

# %%
city_rows = charging_station_vehicle_df[charging_station_vehicle_df['City'] == city_value[0]]
state_values = city_rows['State'].values
print(state_values)
# Out:
# ['CA' 'CA' 'CA' 'CA' 'CA' 'WA' 'CA' 'CA' 'CA' 'CA' 'CA' 'WA' 'CA' 'CA'
#  'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA'
#  'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA'
#  'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA'
#  'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA'
#  'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA'
#  'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA'
#  'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA'
#  'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA'
#  'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA'
#  'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA'
#  'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA'
#  'CA' 'CA' 'NJ' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA'
#  'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA'
#  'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA' 'CA'
#  'CA' 'CA' nan 'CA' 'CA' 'CA' 'CA' 'CA' 'CA']

# %%
#  changes

# Define a list of cities for which we want to fill the missing state values
ca_cities = ['Long Beach', 'Santa Monica', 'Merced', 'San Jose','Dalseong-gun, Daegu','Wendell']
az_cities = ['Phoenix','Goodyear','Scottsdale']
fl_cities = ['Orlando','Hialeah']
or_cities = ['Portland']
nj_cities = ['Paramus']
mn_cities = ['Northfield']
tx_cities = ['Austin','Frisco','Round Rock']
sc_cities = ['Pawleys Island']
in_cities = ['Indianapolis']
co_cities = ['Boulder']
nc_cities = ['Charlotte']


# Fill the missing values in the state column where the city is one of the specified cities
charging_station_vehicle_df.loc[charging_station_vehicle_df['City'].isin(ca_cities) & charging_station_vehicle_df['State'].isnull(), 'State'] = 'CA'
charging_station_vehicle_df.loc[charging_station_vehicle_df['City'].isin(az_cities) & charging_station_vehicle_df['State'].isnull(), 'State'] = 'AZ'
charging_station_vehicle_df.loc[charging_station_vehicle_df['City'].isin(fl_cities) & charging_station_vehicle_df['State'].isnull(), 'State'] = 'FL'
charging_station_vehicle_df.loc[charging_station_vehicle_df['City'].isin(or_cities) & charging_station_vehicle_df['State'].isnull(), 'State'] = 'OR'
charging_station_vehicle_df.loc[charging_station_vehicle_df['City'].isin(nj_cities) & charging_station_vehicle_df['State'].isnull(), 'State'] = 'NJ'
charging_station_vehicle_df.loc[charging_station_vehicle_df['City'].isin(mn_cities) & charging_station_vehicle_df['State'].isnull(), 'State'] = 'MN'
charging_station_vehicle_df.loc[charging_station_vehicle_df['City'].isin(tx_cities) & charging_station_vehicle_df['State'].isnull(), 'State'] = 'TX'
charging_station_vehicle_df.loc[charging_station_vehicle_df['City'].isin(sc_cities) & charging_station_vehicle_df['State'].isnull(), 'State'] = 'SC'
charging_station_vehicle_df.loc[charging_station_vehicle_df['City'].isin(in_cities) & charging_station_vehicle_df['State'].isnull(), 'State'] = 'IN'
charging_station_vehicle_df.loc[charging_station_vehicle_df['City'].isin(co_cities) & charging_station_vehicle_df['State'].isnull(), 'State'] = 'CO'
charging_station_vehicle_df.loc[charging_station_vehicle_df['City'].isin(nc_cities) & charging_station_vehicle_df['State'].isnull(), 'State'] = 'NC'


charging_station_vehicle_df
# Out:
#       Fuel Type Code                                      Station Name  \
# 0               ELEC                     Los Angeles Convention Center
# 1               ELEC                    California Air Resources Board
# 2               ELEC                            Scripps Green Hospital
# 3               ELEC                                     Galpin Motors
# 4               ELEC                                 Galleria at Tyler
# ...              ...                                               ...
# 52131           ELEC  Center of Excellence (For Testing Purposes Only)
# 52132           ELEC                                  HG&E Main Office
# 52133           ELEC                        Hood River Fire Department
# 52134           ELEC                         Cummins- Briston PA Fleet
# 52135           ELEC                    Bayer Chevrolet Buick Cadillac
#
#                 Street Address          City State    ZIP Station Phone  \
# 0           1201 S Figueroa St   Los Angeles    CA  90015  213-741-1151
# 1             9530 Telstar Ave      El Monte    CA  91731  626-575-6800
# 2      10666 N Torrey Pines Rd      La Jolla    CA  92037           NaN
# 3            15421 Roscoe Blvd     Sepulveda    CA  91343  800-256-6219
# 4       1299 Galleria at Tyler     Riverside    CA  92503  951-351-3110
# ...                        ...           ...   ...    ...           ...
# 52131        300 Victory Drive       Herndon    VA  20170  833-632-2778
# 52132        99 Suffolk Street       Holyoke    MA  01040  888-356-8911
# 52133          1785 Meyer Pkwy    Hood River    OR  97031  855-885-9571
# 52134           2727 Ford Road       Briston    PA  19007  855-885-9571
# 52135          601 W Walker St  Breckenridge    TX  76424  866-816-7584
#
#       Status Code           Access Days Time  EV Level1 EVSE Num  \
# 0               E        5:30am-9pm; pay lot                 NaN
# 1               E             24 hours daily                 NaN
# 2               E             24 hours daily                 NaN
# 3               E  Dealership business hours                 NaN
# 4               E             6am-12am daily                 NaN
# ...           ...                        ...                 ...
# 52131           E             24 hours daily                 NaN
# 52132           E             24 hours daily                 NaN
# 52133           E                        NaN                 NaN
# 52134           E                        NaN                 NaN
# 52135           E                        NaN                 NaN
#
#        EV Level2 EVSE Num  EV DC Fast Count Geocode Status   Latitude  \
# 0                     7.0               NaN            GPS  34.040539
# 1                     3.0               NaN            GPS  34.068720
# 2                     1.0               NaN            GPS  32.899470
# 3                     2.0               NaN          200-9  34.221665
# 4                     4.0               NaN            GPS  33.909914
# ...                   ...               ...            ...        ...
# 52131                 NaN               1.0            GPS  38.957440
# 52132                 2.0               NaN          200-8  42.207190
# 52133                 1.0               NaN            GPS  45.703330
# 52134                 2.0               NaN            GPS  40.119151
# 52135                 1.0               NaN            GPS  32.755116
#
#         Longitude      ID Owner Type Code EV Connector Types Country
# 0     -118.271387    1523               P              J1772      US
# 1     -118.064000    1583              SG              J1772      US
# 2     -117.243000    6355               P              J1772      US
# 3     -118.468371    6405               P              J1772      US
# 4     -117.459053    6425               P              J1772      US
# ...           ...     ...             ...                ...     ...
# 52131  -77.378810  258294             NaN         J1772COMBO      US
# 52132  -72.610530  258303             NaN              J1772      US
# 52133 -121.529720  258304             NaN              J1772      US
# 52134  -74.890009  258305             NaN              J1772      US
# 52135  -98.909056  258306             NaN              J1772      US
#
# [52136 rows x 19 columns]

# %%
#Station Phone
charging_station_vehicle_df['Station Phone'].fillna(value="NOT DEFINE", inplace=True)

# %%
null_County_row = charging_station_vehicle_df[charging_station_vehicle_df['EV Connector Types'].isnull()]
charging_station_vehicle_df = charging_station_vehicle_df.dropna(subset=['EV Connector Types'])

# %%
null_County_row = charging_station_vehicle_df[charging_station_vehicle_df['Station Name'].isnull()]
charging_station_vehicle_df = charging_station_vehicle_df.dropna(subset=['Station Name'])

# %%
#Access Days Time
charging_station_vehicle_df['Access Days Time'].fillna(value="24 hours daily", inplace=True)

# %%
#EV Level1 EVSE Num,EV Level2 EVSE Num,EV DC Fast Count
charging_station_vehicle_df['EV Level1 EVSE Num'].fillna(value="0", inplace=True)
charging_station_vehicle_df['EV Level2 EVSE Num'].fillna(value="0", inplace=True)
charging_station_vehicle_df['EV DC Fast Count'].fillna(value="0", inplace=True)

# %%
#Geocode Status
null_GeocodeStatus_row = charging_station_vehicle_df[charging_station_vehicle_df['Geocode Status'].isnull()]
charging_station_vehicle_df = charging_station_vehicle_df.dropna(subset=['Geocode Status'])

# %%
#Owner Type Code
charging_station_vehicle_df['Owner Type Code'].fillna(value="not defined", inplace=True)

# %%
charging_station_vehicle_df
# Out:
#       Fuel Type Code                                      Station Name  \
# 0               ELEC                     Los Angeles Convention Center
# 1               ELEC                    California Air Resources Board
# 2               ELEC                            Scripps Green Hospital
# 3               ELEC                                     Galpin Motors
# 4               ELEC                                 Galleria at Tyler
# ...              ...                                               ...
# 52131           ELEC  Center of Excellence (For Testing Purposes Only)
# 52132           ELEC                                  HG&E Main Office
# 52133           ELEC                        Hood River Fire Department
# 52134           ELEC                         Cummins- Briston PA Fleet
# 52135           ELEC                    Bayer Chevrolet Buick Cadillac
#
#                 Street Address          City State    ZIP Station Phone  \
# 0           1201 S Figueroa St   Los Angeles    CA  90015  213-741-1151
# 1             9530 Telstar Ave      El Monte    CA  91731  626-575-6800
# 2      10666 N Torrey Pines Rd      La Jolla    CA  92037    NOT DEFINE
# 3            15421 Roscoe Blvd     Sepulveda    CA  91343  800-256-6219
# 4       1299 Galleria at Tyler     Riverside    CA  92503  951-351-3110
# ...                        ...           ...   ...    ...           ...
# 52131        300 Victory Drive       Herndon    VA  20170  833-632-2778
# 52132        99 Suffolk Street       Holyoke    MA  01040  888-356-8911
# 52133          1785 Meyer Pkwy    Hood River    OR  97031  855-885-9571
# 52134           2727 Ford Road       Briston    PA  19007  855-885-9571
# 52135          601 W Walker St  Breckenridge    TX  76424  866-816-7584
#
#       Status Code           Access Days Time EV Level1 EVSE Num  \
# 0               E        5:30am-9pm; pay lot                  0
# 1               E             24 hours daily                  0
# 2               E             24 hours daily                  0
# 3               E  Dealership business hours                  0
# 4               E             6am-12am daily                  0
# ...           ...                        ...                ...
# 52131           E             24 hours daily                  0
# 52132           E             24 hours daily                  0
# 52133           E             24 hours daily                  0
# 52134           E             24 hours daily                  0
# 52135           E             24 hours daily                  0
#
#       EV Level2 EVSE Num EV DC Fast Count Geocode Status   Latitude  \
# 0                    7.0                0            GPS  34.040539
# 1                    3.0                0            GPS  34.068720
# 2                    1.0                0            GPS  32.899470
# 3                    2.0                0          200-9  34.221665
# 4                    4.0                0            GPS  33.909914
# ...                  ...              ...            ...        ...
# 52131                  0              1.0            GPS  38.957440
# 52132                2.0                0          200-8  42.207190
# 52133                1.0                0            GPS  45.703330
# 52134                2.0                0            GPS  40.119151
# 52135                1.0                0            GPS  32.755116
#
#         Longitude      ID Owner Type Code EV Connector Types Country
# 0     -118.271387    1523               P              J1772      US
# 1     -118.064000    1583              SG              J1772      US
# 2     -117.243000    6355               P              J1772      US
# 3     -118.468371    6405               P              J1772      US
# 4     -117.459053    6425               P              J1772      US
# ...           ...     ...             ...                ...     ...
# 52131  -77.378810  258294     not defined         J1772COMBO      US
# 52132  -72.610530  258303     not defined              J1772      US
# 52133 -121.529720  258304     not defined              J1772      US
# 52134  -74.890009  258305     not defined              J1772      US
# 52135  -98.909056  258306     not defined              J1772      US
#
# [52112 rows x 19 columns]

# %%
null_counts = charging_station_vehicle_df.isnull().sum()
print(null_counts)
# Out:
# Fuel Type Code        0
# Station Name          0
# Street Address        0
# City                  0
# State                 0
# ZIP                   0
# Station Phone         0
# Status Code           0
# Access Days Time      0
# EV Level1 EVSE Num    0
# EV Level2 EVSE Num    0
# EV DC Fast Count      0
# Geocode Status        0
# Latitude              0
# Longitude             0
# ID                    0
# Owner Type Code       0
# EV Connector Types    0
# Country               0
# dtype: int64
